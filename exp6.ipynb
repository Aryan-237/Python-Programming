# %%
n = int(input("Enter number of values: "))

count0 = 0
count1 = 0
count2 = 0
count3 = 0

for i in range(n):
    num = int(input("Enter a value (0-3): "))

    if num == 0:
        count0 += 1
    elif num == 1:
        count1 += 1
    elif num == 2:
        count2 += 1
    elif num == 3:
        count3 += 1

print("0 occurred", count0, "times")
print("1 occurred", count1, "times")
print("2 occurred", count2, "times")
print("3 occurred", count3, "times")
# Out:
# 0 occurred 0 times
# 1 occurred 1 times
# 2 occurred 1 times
# 3 occurred 1 times

# %%
n = int(input("Enter number of values: "))

values = []

for i in range(n):
    num = int(input("Enter a number: "))
    values.append(num)

t = tuple(values)

total = 0
for x in t:
    total = total + x

average = total / n

print("Tuple:", t)
print("Average:", average)
# Out:
# Tuple: (8, 9, 3, 7, 8)
# Average: 7.0

# %%
n = int(input("Enter number of students: "))

scores = []

for i in range(n):
    score = int(input("Enter score: "))
    scores.append(score)

unique_scores = list(set(scores))

max_score = max(unique_scores)
unique_scores.remove(max_score)

runner_up = max(unique_scores)

print("Runner-up score:", runner_up)
# Out:
# Runner-up score: 5

# %%
n = int(input("Enter number of students: "))

students = {}

for i in range(n):
    name = input("Enter name: ")
    city = input("Enter city: ")
    students[name] = city

print("\nNames of students:")
for name in students.keys():
    print(name)

print("\nCity names:")
for city in students.values():
    print(city)

print("\nStudent details:")
for name, city in students.items():
    print(name, ":", city)

city_count = {}

for city in students.values():
    if city in city_count:
        city_count[city] += 1
    else:
        city_count[city] = 1

print("\nNumber of students in each city:")
for city, count in city_count.items():
    print(city, ":", count)
# Out:
# Names of students:
# aryan
# zaid
# ayush
# alam
# parav
#
# City names:
# dehradun
# haldwani
# haryana
# noida
# harayana
#
# Student details:
# aryan : dehradun
# zaid : haldwani
# ayush : haryana
# alam : noida
# parav : harayana
#
# Number of students in each city:
# dehradun : 1
# haldwani : 1
# haryana : 1
# noida : 1
# harayana : 1

# %%
n = int(input("Enter number of movies: "))

movies = {}

for i in range(n):
    name = input("Enter movie name: ")
    year = int(input("Enter release year: "))
    director = input("Enter director name: ")
    cost = int(input("Enter production cost: "))
    collection = int(input("Enter collection made: "))

    movies[name] = {
        "year": year,
        "director": director,
        "cost": cost,
        "collection": collection
    }

print("\nAll Movie Details:")
for name, details in movies.items():
    print(name, details)

print("\nMovies released before 2015:")
for name, details in movies.items():
    if details["year"] < 2015:
        print(name)

print("\nMovies that made profit:")
for name, details in movies.items():
    if details["collection"] > details["cost"]:
        print(name)

search_director = input("\nEnter director name to search: ")
print("Movies directed by", search_director + ":")
for name, details in movies.items():
    if details["director"] == search_director:
        print(name)
# Out:
# All Movie Details:
# scary movie {'year': 2013, 'director': 'chris', 'cost': 500000, 'collection': 5000000}
# hero movie {'year': 2015, 'director': 'joe', 'cost': 60000, 'collection': 600000}
#
# Movies released before 2015:
# scary movie
#
# Movies that made profit:
# scary movie
# hero movie
# Movies directed by chris:
# scary movie
